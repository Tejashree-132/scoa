# %%
#SCOAL ASSIGNMENT NO. 1
import numpy as np

# ----- Define Fuzzy Sets -----
X = [1, 2, 3, 4, 5]
A = {1: 0.2, 2: 0.7, 3: 1.0, 4: 0.4, 5: 0.1}
B = {1: 0.6, 2: 0.2, 3: 0.9, 4: 0.3, 5: 0.5}

# ----- Fuzzy Set Operations -----
def union(A, B):
    return {x: max(A[x], B[x]) for x in A}

def intersection(A, B):
    return {x: min(A[x], B[x]) for x in A}

def complement(A):
    return {x: 1 - A[x] for x in A}

print("Union:", union(A,B))
print("Intersection:", intersection(A,B))
print("Complement of A:", complement(A))

# ----- Cartesian Product (Fuzzy Relation) -----
def cartesian(A, B):
    return {(x, y): min(A[x], B[y]) for x in A for y in B}

R1 = cartesian(A, B)
R2 = cartesian(B, A)  # another relation

print("\nFuzzy Relation R1 (A x B):")
for pair, val in R1.items():
    print(pair, ":", val)
print("\nFuzzy Relation R2 (B x A):")
for pair, val in R2.items():
    print(pair, ":", val)

# ----- Max-Min Composition -----
def max_min_composition(R1, R2, A_set, B_set, C_set):
    result = {}
    for x in A_set:
        for z in C_set:
            values = []
            for y in B_set:
                values.append(min(R1[(x,y)], R2[(y,z)]))
            result[(x,z)] = max(values)
    return result

Comp = max_min_composition(R1, R2, X, X, X)

print("\nMax-Min Composition (R1 ∘ R2):")
for pair, val in Comp.items():
    print(pair, ":", val)
# Out:
# Union: {1: 0.6, 2: 0.7, 3: 1.0, 4: 0.4, 5: 0.5}
# Intersection: {1: 0.2, 2: 0.2, 3: 0.9, 4: 0.3, 5: 0.1}
# Complement of A: {1: 0.8, 2: 0.30000000000000004, 3: 0.0, 4: 0.6, 5: 0.9}
#
# Fuzzy Relation R1 (A x B):
# (1, 1) : 0.2
# (1, 2) : 0.2
# (1, 3) : 0.2
# (1, 4) : 0.2
# (1, 5) : 0.2
# (2, 1) : 0.6
# (2, 2) : 0.2
# (2, 3) : 0.7
# (2, 4) : 0.3
# (2, 5) : 0.5
# (3, 1) : 0.6
# (3, 2) : 0.2
# (3, 3) : 0.9
# (3, 4) : 0.3
# (3, 5) : 0.5
# (4, 1) : 0.4
# (4, 2) : 0.2
# (4, 3) : 0.4
# (4, 4) : 0.3
# (4, 5) : 0.4
# (5, 1) : 0.1
# (5, 2) : 0.1
# (5, 3) : 0.1
# (5, 4) : 0.1
# (5, 5) : 0.1
#
# Fuzzy Relation R2 (B x A):
# (1, 1) : 0.2
# (1, 2) : 0.6
# (1, 3) : 0.6
# (1, 4) : 0.4
# (1, 5) : 0.1
# (2, 1) : 0.2
# (2, 2) : 0.2
# (2, 3) : 0.2
# (2, 4) : 0.2
# (2, 5) : 0.1
# (3, 1) : 0.2
# (3, 2) : 0.7
# (3, 3) : 0.9
# (3, 4) : 0.4
# (3, 5) : 0.1
# (4, 1) : 0.2
# (4, 2) : 0.3
# (4, 3) : 0.3
# (4, 4) : 0.3
# (4, 5) : 0.1
# (5, 1) : 0.2
# (5, 2) : 0.5
# (5, 3) : 0.5
# (5, 4) : 0.4
# (5, 5) : 0.1
#
# ...

# %% [markdown]
# Step 2: Define the Fuzzy Sets
#
# ```python
# X = [1, 2, 3, 4, 5]
# A = {1: 0.2, 2: 0.7, 3: 1.0, 4: 0.4, 5: 0.1}
# B = {1: 0.6, 2: 0.2, 3: 0.9, 4: 0.3, 5: 0.5}
# ```
#
# Explanation:
#
# * `X` → The **universe of discourse** (a finite set of elements).
# * `A` and `B` → **Fuzzy sets** defined on `X`.
#   Each element in `X` has a **membership value** between 0 and 1.
#
# Example:
#
# In set `A`, the membership value of element `2` is `0.7`.
# This means that `2` belongs to fuzzy set `A` with degree `0.7` (partial membership).
#
# Mathematically:
# [
# A = { (1, 0.2), (2, 0.7), (3, 1.0), (4, 0.4), (5, 0.1) }
# ]
#
# ---
#
# Step 3: Fuzzy Set Operations
#
# Union
#
# ```python
# def union(A, B):
#     return {x: max(A[x], B[x]) for x in A}
# ```
#
# Explanation:
#
# * **Union of fuzzy sets A and B** is defined as:
#   [
#   mu A union B(x) = max(mu_A(x), mu_B(x))
#   ]
# * So for each element `x`, we take the **maximum** of its membership values in `A` and `B`.
#
# Python implementation uses a **dictionary comprehension**:
#
# ```python
# {x: max(A[x], B[x]) for x in A}
# ```
#
# ---
#
# Intersection
#
# ```python
# def intersection(A, B):
#     return {x: min(A[x], B[x]) for x in A}
# ```
#
# Explanation:
#
# * **Intersection of fuzzy sets A and B** is defined as:
#   [
#   mu A intersection B(x) = min(mu_A(x), mu_B(x))
#   ]
# * So for each element, we take the **minimum** of its membership values in both sets.
#
# ---
#
# Complement
#
# ```python
# def complement(A):
#     return {x: 1 - A[x] for x in A}
# ```
#
# Explanation:
#
# * The **complement of fuzzy set A** is:
#   [
#   \mu A ^bar(x) = 1 - mu_A(x)
#   ]
# * This gives how much an element does **not belong** to `A`.
#
# ---
#
# Printing the Results
#
# ```python
# print("Union:", union(A,B))
# print("Intersection:", intersection(A,B))
# print("Complement of A:", complement(A))
# ```
#
# Displays:
#
# * Union of A and B
# * Intersection of A and B
# * Complement of A
#
# ---
#
# Step 4: Fuzzy Relation (Cartesian Product)
#
# ```python
# def cartesian(A, B):
#     return {(x, y): min(A[x], B[y]) for x in A for y in B}
# ```
#
# Explanation:
#
# This defines a **fuzzy relation** ( R ∈ A × B ).
#
# Mathematically:
# [
# mu_{R}(x, y) = min(mu_A(x), mu_B(y))
# ]
#
# * Each pair `(x, y)` is formed by taking one element from `A` and one from `B`.
# * Membership value = the **minimum** of their degrees in `A` and `B`.
#
# So the **Cartesian product** gives all possible pairs between elements of A and B, with fuzzy strength values.
#
# ---
#
# Create Two Relations
#
# ```python
# R1 = cartesian(A, B)
# R2 = cartesian(B, A)  # another relation
# ```
#
# * `R1` represents the relation A × B
# * `R2` represents B × A
#
# ---
#
# Printing the Relations
#
# ```python
# print("\nFuzzy Relation R1 (A x B):")
# for pair, val in R1.items():
#     print(pair, ":", val)
# print("\nFuzzy Relation R2 (B x A):")
# for pair, val in R2.items():
#     print(pair, ":", val)
# ```
#
# This prints all pairs `(x, y)` with their membership values.
#
# Example:
#
# ```
# (1,1): 0.2
# (1,2): 0.2
# (2,3): 0.7
# ...
# ```
#
# ---
#
# Step 5: Max–Min Composition
#
# This is the most important part — it represents the **composition of two fuzzy relations**.
#
# ```python
# def max_min_composition(R1, R2, A_set, B_set, C_set):
#     result = {}
#     for x in A_set:
#         for z in C_set:
#             values = []
#             for y in B_set:
#                 values.append(min(R1[(x,y)], R2[(y,z)]))
#             result[(x,z)] = max(values)
#     return result
# ```
#
# ---
#
# Mathematical Explanation:
#
# Let:
#
# * ( R1 ∈ A × B )
# * ( R2 ∈ B × C )
#
# Then their **max–min composition** ( R1 . R2 ∈ A × C ) is defined as:
#
# [
# mu_ R1 . R2(x, z) = max_{y ∈ B} [min(mu_R1 (x, y), mu_R2(y, z))]
# ]
#
# Steps:
#
# 1. For every pair `(x, z)`:
#
#    * Iterate through all possible middle elements `y ∈ B`.
# 2. For each `y`, calculate:
#    [
#    min(R1(x, y), R2(y, z))
#    ]
# 3. Take the **maximum** of all these minimum values.
#
# Hence “**max–min composition**”.
#
# ---
#
# ### ✅ Calling the Function
#
# ```python
# Comp = max_min_composition(R1, R2, X, X, X)
# ```
#
# * Composes R1 and R2 (relations over same universe X).
#
# ---
#
# ### ✅ Displaying the Composition Result
#
# ```python
# print("\nMax-Min Composition (R1 ∘ R2):")
# for pair, val in Comp.items():
#     print(pair, ":", val)
# ```
#
# ---
#
# ## 🔹 Summary of Functions and Equations
#
# | Operation               | Mathematical Formula                                      | Python Logic                      |
# | ----------------------- | --------------------------------------------------------- | --------------------------------- |
# | **Union**               | ( μ_{A∪B}(x) = max(μ_A(x), μ_B(x)) )                      | `max(A[x], B[x])`                 |
# | **Intersection**        | ( μ_{A∩B}(x) = min(μ_A(x), μ_B(x)) )                      | `min(A[x], B[x])`                 |
# | **Complement**          | ( μ_{¬A}(x) = 1 - μ_A(x) )                                | `1 - A[x]`                        |
# | **Cartesian Product**   | ( μ_R(x,y) = min(μ_A(x), μ_B(y)) )                        | `min(A[x], B[y])`                 |
# | **Max–Min Composition** | ( μ_{R1∘R2}(x,z) = max_y[min(μ_{R1}(x,y), μ_{R2}(y,z))] ) | Nested loops with `max` and `min` |
#
# ---
#
# ## 🔹 Concept Diagram (Textual)
#
# ```
# A ----R1----> B ----R2----> C
#  |                      |
#  |------ R1∘R2 ---------|
# ```
#
# * Each arrow is a fuzzy relation.
# * The composition R1∘R2 connects A to C indirectly via B.
#
# ---
#
#
#
#
# Theory:
#
# introduction:
#
# Fuzzy set theory is an extension of classical set theory where elements have degrees of membership ranging from 0 to 1, instead of a crisp belonging (either 0 or 1). This concept is widely used in decision-making, artificial intelligence, and control systems where uncertainties and vagueness exist. In this assignment, we implement basic operations on fuzzy sets, create fuzzy relations using the Cartesian product, and perform max-min composition on fuzzy relations.
#
#
# Mathematical Operations on Fuzzy Sets
#
# Let two fuzzy sets A and B be defined on a common universe X. The membership function of each element x ∈ X is denoted by μA(x) and μB(x). The basic fuzzy set operations are:
#
#  1. Union: μA∪B(x) = max(μA(x), μB(x))
#
#  2. Intersection: μA∩B(x) = min(μA(x), μB(x))
#
#  3. Complement: μA′(x) = 1 - μA(x)
#
#
# Fuzzy Relations and Cartesian Product
#
# A fuzzy relation R between two fuzzy sets A (on universe X) and B (on universe Y) is represented by the Cartesian product:
#
#  R(x,y) = min(μA(x), μB(y)) for all (x,y) ∈ X × Y
#
#  This produces a fuzzy relation matrix where each entry represents the degree of association between elements of X and Y.
#
#
# Max-Min Composition of Fuzzy Relations
#
# Given two fuzzy relations R1 (between sets X and Y) and R2 (between sets Y and Z), the max-min composition R = R1 ∘ R2 is defined as:
#
#  R(x,z) = max_y [ min(R1(x,y), R2(y,z)) ]
#
#  This operation combines two relations into a single relation representing indirect association between X and Z via Y.
#
#
# Example Implementation
#
# Consider fuzzy sets A and B defined over the universe {1, 2, 3}:
#
# A = { (1, 0.2), (2, 0.7), (3, 1.0) }
#
# B = { (1, 0.5), (2, 0.4), (3, 0.9) }
#
# Union: μA∪B = { (1, 0.5), (2, 0.7), (3, 1.0) }
#
# Intersection: μA∩B = { (1, 0.2), (2, 0.4), (3, 0.9) }
#
# Complement of A: { (1, 0.8), (2, 0.3), (3, 0.0) }
#
# Fuzzy relation R from A × B:
#
# R = [ [min(0.2,0.5), min(0.2,0.4), min(0.2,0.9)],
#
#   	[min(0.7,0.5), min(0.7,0.4), min(0.7,0.9)],
#
#   	[min(1.0,0.5), min(1.0,0.4), min(1.0,0.9)] ]
#
# Max-min composition can then be applied between two relations R1 and R2 to compute indirect associations.
#
#
# Results:
#
# The program successfully computed fuzzy union, intersection, and complement.
#
# Fuzzy relations were constructed as a matrix-like structure.
#
# Max–min composition produced another fuzzy relation that combined the two given relations.
#
#
# Conclusion:
#
# This assignment demonstrated the practical implementation of fuzzy set operations and fuzzy relations. The results illustrate how fuzzy logic handles uncertainty and provides a foundation for applications in decision-making, expert systems, and artificial intelligence.
